# %% [markdown]
# # Scrapping Data Ulasan Mobile Legends

# %% [markdown]
# ## Import Library yang dibutuhkan

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort
import time
import pandas as pd  # Pandas untuk manipulasi dan analisis data
import os
pd.options.mode.chained_assignment = None  # Menonaktifkan peringatan chaining

# %% [markdown]
# ## Scrapping Data

# %%
# Mengambil semua ulasan dari aplikasi dengan ID 'com.byu.id' di Google Play Store.
# Proses scraping mungkin memerlukan beberapa saat tergantung pada jumlah ulasan yang ada.
all_reviews = []
continuation_token = None  # Token untuk melanjutkan dari batch sebelumnya
total_target = 70000  # Target jumlah ulasan
batch_size = 200      # Maksimal per request

print("Mulai scraping...")

while len(all_reviews) < total_target:
    print(f"Batch {len(all_reviews)//batch_size + 1} - Total: {len(all_reviews)} ulasan")

    result, continuation_token = reviews(
        app_id= 'com.mobile.legends',   # ID aplikasi
        lang= 'en',                     # Bahasa Indonesia
        country= 'us',                  # Lokasi Indonesia
        sort= Sort.MOST_RELEVANT,       # Urutan ulasan (Paling Relevan)
        count= batch_size,              # Jumlah ulasan per batch
        continuation_token= continuation_token,       # Token untuk melanjutkan dari batch sebelumnya
        filter_score_with= None         # Filter berdasarkan skor (None untuk semua)
    )

    all_reviews.extend(result)

    if continuation_token is None:
        print("Tidak ada ulasan lagi yang bisa diambil.")
        break

    time.sleep(1)  # Biar nggak terlalu cepat request-nya

# Simpan ke DataFrame
df = pd.DataFrame(all_reviews)

# Pastikan folder 'data' ada
os.makedirs('data', exist_ok=True)

# Simpan hasil ke file CSV di folder 'data'
df.to_csv('data/ulasan_mobile_legends_70k.csv', index=False, encoding='utf-8-sig')
print(f"Scraping selesai! Total ulasan yang didapat: {len(df)}")
# Out:
# Mulai scraping...
# Batch 1 - Total: 0 ulasan
# Batch 2 - Total: 200 ulasan
# Batch 3 - Total: 400 ulasan
# Batch 4 - Total: 600 ulasan
# Batch 5 - Total: 800 ulasan
# Batch 6 - Total: 1000 ulasan
# Batch 7 - Total: 1200 ulasan
# Batch 8 - Total: 1400 ulasan
# Batch 9 - Total: 1600 ulasan
# Batch 10 - Total: 1800 ulasan
# Batch 11 - Total: 2000 ulasan
# Batch 12 - Total: 2200 ulasan
# Batch 13 - Total: 2400 ulasan
# Batch 14 - Total: 2600 ulasan
# Batch 15 - Total: 2800 ulasan
# Batch 16 - Total: 3000 ulasan
# Batch 17 - Total: 3200 ulasan
# Batch 18 - Total: 3400 ulasan
# Batch 19 - Total: 3600 ulasan
# Batch 20 - Total: 3800 ulasan
# Batch 21 - Total: 4000 ulasan
# Batch 22 - Total: 4200 ulasan
# Batch 23 - Total: 4400 ulasan
# Batch 24 - Total: 4600 ulasan
# Batch 25 - Total: 4800 ulasan
# Batch 26 - Total: 5000 ulasan
# Batch 27 - Total: 5200 ulasan
# Batch 28 - Total: 5400 ulasan
# Batch 29 - Total: 5600 ulasan
# Batch 30 - Total: 5800 ulasan
# Batch 31 - Total: 6000 ulasan
# Batch 32 - Total: 6200 ulasan
# Batch 33 - Total: 6400 ulasan
# Batch 34 - Total: 6600 ulasan
# Batch 35 - Total: 6800 ulasan
# Batch 36 - Total: 7000 ulasan
# Batch 37 - Total: 7200 ulasan
# Batch 38 - Total: 7400 ulasan
# Batch 39 - Total: 7600 ulasan
# Batch 40 - Total: 7800 ulasan
# Batch 41 - Total: 8000 ulasan
# Batch 42 - Total: 8200 ulasan
# Batch 43 - Total: 8400 ulasan
# Batch 44 - Total: 8600 ulasan
# Batch 45 - Total: 8800 ulasan
# Batch 46 - Total: 9000 ulasan
# Batch 47 - Total: 9200 ulasan
# Batch 48 - Total: 9400 ulasan
# Batch 49 - Total: 9600 ulasan
# Batch 50 - Total: 9800 ulasan
# Batch 51 - Total: 10000 ulasan
# Batch 52 - Total: 10200 ulasan
# Batch 53 - Total: 10400 ulasan
# Batch 54 - Total: 10600 ulasan
# Batch 55 - Total: 10800 ulasan
# Batch 56 - Total: 11000 ulasan
# Batch 57 - Total: 11200 ulasan
# Batch 58 - Total: 11400 ulasan
# Batch 59 - Total: 11600 ulasan
# Batch 60 - Total: 11800 ulasan
# Batch 61 - Total: 12000 ulasan
# Batch 62 - Total: 12200 ulasan
# Batch 63 - Total: 12400 ulasan
# Batch 64 - Total: 12600 ulasan
# Batch 65 - Total: 12800 ulasan
# Batch 66 - Total: 13000 ulasan
# Batch 67 - Total: 13200 ulasan
# Batch 68 - Total: 13400 ulasan
# Batch 69 - Total: 13600 ulasan
# Batch 70 - Total: 13800 ulasan
# Batch 71 - Total: 14000 ulasan
# Batch 72 - Total: 14200 ulasan
# Batch 73 - Total: 14400 ulasan
# Batch 74 - Total: 14600 ulasan
# Batch 75 - Total: 14800 ulasan
# Batch 76 - Total: 15000 ulasan
# Batch 77 - Total: 15200 ulasan
# Batch 78 - Total: 15400 ulasan
# Batch 79 - Total: 15600 ulasan
# Batch 80 - Total: 15800 ulasan
# Batch 81 - Total: 16000 ulasan
# Batch 82 - Total: 16200 ulasan
# Batch 83 - Total: 16400 ulasan
# Batch 84 - Total: 16600 ulasan
# Batch 85 - Total: 16800 ulasan
# Batch 86 - Total: 17000 ulasan
# Batch 87 - Total: 17200 ulasan
# Batch 88 - Total: 17400 ulasan
# Batch 89 - Total: 17600 ulasan
# Batch 90 - Total: 17800 ulasan
# Batch 91 - Total: 18000 ulasan
# Batch 92 - Total: 18200 ulasan
# Batch 93 - Total: 18400 ulasan
# Batch 94 - Total: 18600 ulasan
# Batch 95 - Total: 18800 ulasan
# Batch 96 - Total: 19000 ulasan
# Batch 97 - Total: 19200 ulasan
# Batch 98 - Total: 19400 ulasan
# Batch 99 - Total: 19600 ulasan
# Batch 100 - Total: 19800 ulasan
# Batch 101 - Total: 20000 ulasan
# Batch 102 - Total: 20200 ulasan
# Batch 103 - Total: 20400 ulasan
# Batch 104 - Total: 20600 ulasan
# Batch 105 - Total: 20800 ulasan
# Batch 106 - Total: 21000 ulasan
# Batch 107 - Total: 21200 ulasan
# Batch 108 - Total: 21400 ulasan
# Batch 109 - Total: 21600 ulasan
# Batch 110 - Total: 21800 ulasan
# Batch 111 - Total: 22000 ulasan
# Batch 112 - Total: 22200 ulasan
# Batch 113 - Total: 22400 ulasan
# Batch 114 - Total: 22600 ulasan
# Batch 115 - Total: 22800 ulasan
# Batch 116 - Total: 23000 ulasan
# Batch 117 - Total: 23200 ulasan
# Batch 118 - Total: 23400 ulasan
# Batch 119 - Total: 23600 ulasan
# Batch 120 - Total: 23800 ulasan
# Batch 121 - Total: 24000 ulasan
# Batch 122 - Total: 24200 ulasan
# Batch 123 - Total: 24400 ulasan
# Batch 124 - Total: 24600 ulasan
# Batch 125 - Total: 24800 ulasan
# Batch 126 - Total: 25000 ulasan
# Batch 127 - Total: 25200 ulasan
# Batch 128 - Total: 25400 ulasan
# Batch 129 - Total: 25600 ulasan
# Batch 130 - Total: 25800 ulasan
# Batch 131 - Total: 26000 ulasan
# Batch 132 - Total: 26200 ulasan
# Batch 133 - Total: 26400 ulasan
# Batch 134 - Total: 26600 ulasan
# Batch 135 - Total: 26800 ulasan
# Batch 136 - Total: 27000 ulasan
# Batch 137 - Total: 27200 ulasan
# Batch 138 - Total: 27400 ulasan
# Batch 139 - Total: 27600 ulasan
# Batch 140 - Total: 27800 ulasan
# Batch 141 - Total: 28000 ulasan
# Batch 142 - Total: 28200 ulasan
# Batch 143 - Total: 28400 ulasan
# Batch 144 - Total: 28600 ulasan
# Batch 145 - Total: 28800 ulasan
# Batch 146 - Total: 29000 ulasan
# Batch 147 - Total: 29200 ulasan
# Batch 148 - Total: 29400 ulasan
# Batch 149 - Total: 29600 ulasan
# Batch 150 - Total: 29800 ulasan
# Batch 151 - Total: 30000 ulasan
# Batch 152 - Total: 30200 ulasan
# Batch 153 - Total: 30400 ulasan
# Batch 154 - Total: 30600 ulasan
# Batch 155 - Total: 30800 ulasan
# Batch 156 - Total: 31000 ulasan
# Batch 157 - Total: 31200 ulasan
# Batch 158 - Total: 31400 ulasan
# Batch 159 - Total: 31600 ulasan
# Batch 160 - Total: 31800 ulasan
# Batch 161 - Total: 32000 ulasan
# Batch 162 - Total: 32200 ulasan
# Batch 163 - Total: 32400 ulasan
# Batch 164 - Total: 32600 ulasan
# Batch 165 - Total: 32800 ulasan
# Batch 166 - Total: 33000 ulasan
# Batch 167 - Total: 33200 ulasan
# Batch 168 - Total: 33400 ulasan
# Batch 169 - Total: 33600 ulasan
# Batch 170 - Total: 33800 ulasan
# Batch 171 - Total: 34000 ulasan
# Batch 172 - Total: 34200 ulasan
# Batch 173 - Total: 34400 ulasan
# Batch 174 - Total: 34600 ulasan
# Batch 175 - Total: 34800 ulasan
# Batch 176 - Total: 35000 ulasan
# Batch 177 - Total: 35200 ulasan
# Batch 178 - Total: 35400 ulasan
# Batch 179 - Total: 35600 ulasan
# Batch 180 - Total: 35800 ulasan
# Batch 181 - Total: 36000 ulasan
# Batch 182 - Total: 36200 ulasan
# Batch 183 - Total: 36400 ulasan
# Batch 184 - Total: 36600 ulasan
# Batch 185 - Total: 36800 ulasan
# Batch 186 - Total: 37000 ulasan
# Batch 187 - Total: 37200 ulasan
# Batch 188 - Total: 37400 ulasan
# Batch 189 - Total: 37600 ulasan
# Batch 190 - Total: 37800 ulasan
# Batch 191 - Total: 38000 ulasan
# Batch 192 - Total: 38200 ulasan
# Batch 193 - Total: 38400 ulasan
# Batch 194 - Total: 38600 ulasan
# Batch 195 - Total: 38800 ulasan
# Batch 196 - Total: 39000 ulasan
# Batch 197 - Total: 39200 ulasan
# Batch 198 - Total: 39400 ulasan
# Batch 199 - Total: 39600 ulasan
# Batch 200 - Total: 39800 ulasan
# Batch 201 - Total: 40000 ulasan
# Batch 202 - Total: 40200 ulasan
# Batch 203 - Total: 40400 ulasan
# Batch 204 - Total: 40600 ulasan
# Batch 205 - Total: 40800 ulasan
# Batch 206 - Total: 41000 ulasan
# Batch 207 - Total: 41200 ulasan
# Batch 208 - Total: 41400 ulasan
# Batch 209 - Total: 41600 ulasan
# Batch 210 - Total: 41800 ulasan
# Batch 211 - Total: 42000 ulasan
# Batch 212 - Total: 42200 ulasan
# Batch 213 - Total: 42400 ulasan
# Batch 214 - Total: 42600 ulasan
# Batch 215 - Total: 42800 ulasan
# Batch 216 - Total: 43000 ulasan
# Batch 217 - Total: 43200 ulasan
# Batch 218 - Total: 43400 ulasan
# Batch 219 - Total: 43600 ulasan
# Batch 220 - Total: 43800 ulasan
# Batch 221 - Total: 44000 ulasan
# Batch 222 - Total: 44200 ulasan
# Batch 223 - Total: 44400 ulasan
# Batch 224 - Total: 44600 ulasan
# Batch 225 - Total: 44800 ulasan
# Batch 226 - Total: 45000 ulasan
# Batch 227 - Total: 45200 ulasan
# Batch 228 - Total: 45400 ulasan
# Batch 229 - Total: 45600 ulasan
# Batch 230 - Total: 45800 ulasan
# Batch 231 - Total: 46000 ulasan
# Batch 232 - Total: 46200 ulasan
# Batch 233 - Total: 46400 ulasan
# Batch 234 - Total: 46600 ulasan
# Batch 235 - Total: 46800 ulasan
# Batch 236 - Total: 47000 ulasan
# Batch 237 - Total: 47200 ulasan
# Batch 238 - Total: 47400 ulasan
# Batch 239 - Total: 47600 ulasan
# Batch 240 - Total: 47800 ulasan
# Batch 241 - Total: 48000 ulasan
# Batch 242 - Total: 48200 ulasan
# Batch 243 - Total: 48400 ulasan
# Batch 244 - Total: 48600 ulasan
# Batch 245 - Total: 48800 ulasan
# Batch 246 - Total: 49000 ulasan
# Batch 247 - Total: 49200 ulasan
# Batch 248 - Total: 49400 ulasan
# Batch 249 - Total: 49600 ulasan
# Batch 250 - Total: 49800 ulasan
# Batch 251 - Total: 50000 ulasan
# Batch 252 - Total: 50200 ulasan
# Batch 253 - Total: 50400 ulasan
# Batch 254 - Total: 50600 ulasan
# Batch 255 - Total: 50800 ulasan
# Batch 256 - Total: 51000 ulasan
# Batch 257 - Total: 51200 ulasan
# Batch 258 - Total: 51400 ulasan
# Batch 259 - Total: 51600 ulasan
# Batch 260 - Total: 51800 ulasan
# Batch 261 - Total: 52000 ulasan
# Batch 262 - Total: 52200 ulasan
# Batch 263 - Total: 52400 ulasan
# Batch 264 - Total: 52600 ulasan
# Batch 265 - Total: 52800 ulasan
# Batch 266 - Total: 53000 ulasan
# Batch 267 - Total: 53200 ulasan
# Batch 268 - Total: 53400 ulasan
# Batch 269 - Total: 53600 ulasan
# Batch 270 - Total: 53800 ulasan
# Batch 271 - Total: 54000 ulasan
# Batch 272 - Total: 54200 ulasan
# Batch 273 - Total: 54400 ulasan
# Batch 274 - Total: 54600 ulasan
# Batch 275 - Total: 54800 ulasan
# Batch 276 - Total: 55000 ulasan
# Batch 277 - Total: 55200 ulasan
# Batch 278 - Total: 55400 ulasan
# Batch 279 - Total: 55600 ulasan
# Batch 280 - Total: 55800 ulasan
# Batch 281 - Total: 56000 ulasan
# Batch 282 - Total: 56200 ulasan
# Batch 283 - Total: 56400 ulasan
# Batch 284 - Total: 56600 ulasan
# Batch 285 - Total: 56800 ulasan
# Batch 286 - Total: 57000 ulasan
# Batch 287 - Total: 57200 ulasan
# Batch 288 - Total: 57400 ulasan
# Batch 289 - Total: 57600 ulasan
# Batch 290 - Total: 57800 ulasan
# Batch 291 - Total: 58000 ulasan
# Batch 292 - Total: 58200 ulasan
# Batch 293 - Total: 58400 ulasan
# Batch 294 - Total: 58600 ulasan
# Batch 295 - Total: 58800 ulasan
# Batch 296 - Total: 59000 ulasan
# Batch 297 - Total: 59200 ulasan
# Batch 298 - Total: 59400 ulasan
# Batch 299 - Total: 59600 ulasan
# Batch 300 - Total: 59800 ulasan
# Batch 301 - Total: 60000 ulasan
# Batch 302 - Total: 60200 ulasan
# Batch 303 - Total: 60400 ulasan
# Batch 304 - Total: 60600 ulasan
# Batch 305 - Total: 60800 ulasan
# Batch 306 - Total: 61000 ulasan
# Batch 307 - Total: 61200 ulasan
# Batch 308 - Total: 61400 ulasan
# Batch 309 - Total: 61600 ulasan
# Batch 310 - Total: 61800 ulasan
# Batch 311 - Total: 62000 ulasan
# Batch 312 - Total: 62200 ulasan
# Batch 313 - Total: 62400 ulasan
# Batch 314 - Total: 62600 ulasan
# Batch 315 - Total: 62800 ulasan
# Batch 316 - Total: 63000 ulasan
# Batch 317 - Total: 63200 ulasan
# Batch 318 - Total: 63400 ulasan
# Batch 319 - Total: 63600 ulasan
# Batch 320 - Total: 63800 ulasan
# Batch 321 - Total: 64000 ulasan
# Batch 322 - Total: 64200 ulasan
# Batch 323 - Total: 64400 ulasan
# Batch 324 - Total: 64600 ulasan
# Batch 325 - Total: 64800 ulasan
# Batch 326 - Total: 65000 ulasan
# Batch 327 - Total: 65200 ulasan
# Batch 328 - Total: 65400 ulasan
# Batch 329 - Total: 65600 ulasan
# Batch 330 - Total: 65800 ulasan
# Batch 331 - Total: 66000 ulasan
# Batch 332 - Total: 66200 ulasan
# Batch 333 - Total: 66400 ulasan
# Batch 334 - Total: 66600 ulasan
# Batch 335 - Total: 66800 ulasan
# Batch 336 - Total: 67000 ulasan
# Batch 337 - Total: 67200 ulasan
# Batch 338 - Total: 67400 ulasan
# Batch 339 - Total: 67600 ulasan
# Batch 340 - Total: 67800 ulasan
# Batch 341 - Total: 68000 ulasan
# Batch 342 - Total: 68200 ulasan
# Batch 343 - Total: 68400 ulasan
# Batch 344 - Total: 68600 ulasan
# Batch 345 - Total: 68800 ulasan
# Batch 346 - Total: 69000 ulasan
# Batch 347 - Total: 69200 ulasan
# Batch 348 - Total: 69400 ulasan
# Batch 349 - Total: 69600 ulasan
# Batch 350 - Total: 69800 ulasan
# Scraping selesai! Total ulasan yang didapat: 70000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              70000 non-null  object
#  1   userName              70000 non-null  object
#  2   userImage             70000 non-null  object
#  3   content               70000 non-null  object
#  4   score                 70000 non-null  int64
#  5   thumbsUpCount         70000 non-null  int64
#  6   reviewCreatedVersion  56638 non-null  object
#  7   at                    70000 non-null  datetime64[ns]
#  8   replyContent          1749 non-null   object
#  9   repliedAt             1749 non-null   datetime64[ns]
#  10  appVersion            56638 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 5.9+ MB

# %%
df.head()
# Out:
#                                reviewId            userName  \
# 0  7c6c4516-bb9a-4106-a518-ebdceb36dade  Phillip Fiorentino
# 1  fd69039f-0df1-4fd1-9a7c-efaae32c7f1d           DarkPot8o
# 2  b1866b78-45c6-41a0-b547-85cb0690bcb5         Nammy Jembe
# 3  05575c33-897d-4338-b874-c83ac2238e72       Julianna Vang
# 4  fe0aeedd-8fc7-45ac-9ce1-18cb3860f57d            Usoro A.
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/ALV-U...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Basically a better and more intuitive version ...      2            190
# 1  I like the game. It's programmed well and bugs...      2            783
# 2  It was good at first, but each time the app up...      3            649
# 3  FIX MATCHMAKING. I cannot stand the one-sided ...      1            369
# 4  The old Legend skins are completely outdated a...      2           1967
#
#   reviewCreatedVersion                  at replyContent repliedAt  \
# 0         1.9.64.10601 2025-04-16 11:10:47         None       NaT
# 1         1.9.64.10601 2025-04-08 21:10:01         None       NaT
# 2         1.9.64.10601 2025-04-15 22:42:06         None       NaT
# 3         1.9.64.10601 2025-03-26 11:51:50         None       NaT
# 4         1.9.64.10601 2025-04-01 14:11:28         None       NaT
#
#      appVersion
# 0  1.9.64.10601
# 1  1.9.64.10601
# 2  1.9.64.10601
# 3  1.9.64.10601
# 4  1.9.64.10601
